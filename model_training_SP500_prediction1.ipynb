# %%
from google.colab import drive
drive.mount('/content/drive')
# !unrar x '/content/drive/My Drive/COMP4211/data_prediction1.rar'
# Out:
# Mounted at /content/drive
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/drive/My Drive/COMP4211/data_prediction1.rar
#
# Creating    data                                                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    data/price                                                OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    data/train_data                                           OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
from tensorflow.keras.utils import Sequence
import tensorflow.keras.backend as K
from tensorflow.keras.optimizers import Adam
from keras.models import Model
from tensorflow.keras.layers import Concatenate,Embedding ,Dense ,Input,LSTM,Permute,Softmax,Lambda,Flatten,GRU,Dropout,BatchNormalization, Normalization, Attention, Bidirectional, Masking, TimeDistributed, AveragePooling1D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from tensorflow.keras.metrics import F1Score, Accuracy
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
# !pip install tensorflow-addons
# !pip install scikit-learn --upgrade
import tensorflow_addons as tfa
from tensorflow.keras.losses import BinaryCrossentropy
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import h5py
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import pickle
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (24.0)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 32.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.4.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed scikit-learn-1.4.2
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
class DataGenerator(Sequence):

    def __init__(self, meta_df, batch_size=64, use_full=False, input_shape=(20,6), label_shape=(20,), minmax=None, **kwargs):
        super().__init__(**kwargs)
        self.ds_pointer = 0
        self.batch_size = batch_size
        self.input_shape=input_shape
        self.use_full = use_full
        self.meta_df = meta_df
        self.minmax = minmax
        self.data = self.load_file()
        self.input_buffer = np.zeros((batch_size,input_shape[0],input_shape[1]))
        self.label_buffer = np.zeros((batch_size,label_shape[0]))
        self.reset_pointer()

    def load_file(self):
        result = {}
        for root, _, files in os.walk('data/train_data'):
            for file in files:
                if f'.h5' in file:
                    symbol = file.split('.')[0]
                    df = pd.read_csv(f'data/price/{symbol}.csv')
                    result[symbol] = h5py.File(f'data/train_data/{symbol}.h5', 'r', rdcc_nbytes=100*1024**2, rdcc_nslots=1e4)
        return result

    def reset_pointer(self, seed = 1314):
        self.meta_df = self.meta_df.sample(frac=1, random_state=seed)
        self.ds_pointer = 0

    def __len__(self):
        if self.use_full:
            return len(self.meta_df)// self.batch_size
        else:
            return len(self.meta_df)// self.batch_size// 10

    def num_labels(self):
        return len(self.label_name)

    def upsample(self):
      # Find the maximum count of labels in the DataFrame
      max_count = self.meta_df['Gloss'].value_counts().max()

      # Define a function to resample and reset index for each group
      def resample_and_reset_index(group):
          resampled_group = group.sample(max_count, replace=True)
          return resampled_group

      # Apply the function to each group and concatenate them back into a single DataFrame
      self.meta_df = self.meta_df.groupby('Label').apply(resample_and_reset_index).reset_index(drop=True)

    def __getitem__(self, index):
        import os
        import numpy as np
        if self.ds_pointer + self.batch_size >= len(self.meta_df):
            self.reset_pointer()
            return self.__getitem__(index)
        to_get = self.meta_df.iloc[self.ds_pointer:self.ds_pointer+ self.batch_size]
        to_get_index = to_get['Index'].to_numpy()
        to_get_symbol = to_get['Symbol'].to_numpy()

        for i, symbol in enumerate(to_get_symbol):
            to_fetch = self.data[symbol]
            self.input_buffer[i, :, :] = to_fetch['data'][to_get_index[i]]
            self.label_buffer[i, :] = to_fetch['label'][to_get_index[i]]

        batch_x = self.input_buffer
        batch_y = self.label_buffer
        if self.minmax is not None:
          batch_x = batch_x.reshape(-1,self.input_shape[1])
          batch_x = self.minmax.transform(batch_x)
          batch_x = batch_x.reshape(-1,self.input_shape[0],self.input_shape[1])
          batch_y = batch_y.reshape(-1,self.input_shape[1])
          batch_y = self.minmax.transform(batch_y)
          batch_y = batch_y.reshape(-1,self.input_shape[0],self.input_shape[1])

        self.ds_pointer+=self.batch_size
        return batch_x, batch_y

# %%
def build_model(time_series,num_of_features, scaler=None, init_neuron=16, learning_rate=0.0001):
    K.clear_session()
    input_ = Input(shape=(time_series,num_of_features), name='Input')
    if scaler is not None:
      mean = scaler.mean_
      print(mean[0:5])
      var = scaler.var_
      norm = Normalization(mean=mean, variance=var,name='Normalization')
      norm = norm(input_)
      input_dense = norm
    else:
      input_dense = input_

    # Define GRU layer
    encoder = GRU(init_neuron, return_state=True, return_sequences=True, name='Encoder')
    encoder_outputs, state_h = encoder(input_dense)

    # # Define attention layer
    attention = Attention(name='Attention')
    context_vector = attention([encoder_outputs, state_h])

    # Concatenate context vector and encoder outputs
    concat_layer = Concatenate(axis=-1, name='Concatenate')
    decoder_combined_context = concat_layer([context_vector, input_dense])

    # Define decoder
    decoder_gru = GRU(init_neuron, return_sequences=False, name='Decoder')

    # Pass the concatenated input through the decoder
    decoder_output = decoder_gru(decoder_combined_context, initial_state=state_h)
    output = Flatten()(decoder_output)
    output = Dense(1)(output)

    model = Model(inputs = input_ , outputs = output)
    adam_optimizer = Adam(learning_rate=learning_rate, weight_decay=1e-7)
    model.compile(loss='binary_crossentropy',optimizer=adam_optimizer,metrics=['binary_accuracy',tfa.metrics.F1Score(1,average='weighted')])
    model.summary()
    return model

# %%
# Model Config
batch_size = 64
time_series = 52
num_features = 6
label_shape = (1,)
input_shape = (time_series,num_features)

meta_df = pd.read_csv('data/meta_SP500.csv',index_col=0)
train_meta, test_meta = train_test_split(meta_df, test_size=0.2, random_state=4211)

# file = open(f'data/minmax_SP500.pkl','rb')
# minmax=pickle.load(file)
minmax=None
# display(train_meta)
# display(test_meta)
train_generator = DataGenerator(train_meta,input_shape=input_shape, batch_size=batch_size, minmax=minmax,label_shape=label_shape)
val_generator = DataGenerator(test_meta,input_shape=input_shape, batch_size=batch_size, minmax=minmax, use_full=True,label_shape=label_shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.4.0 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
x, y = train_generator.__getitem__(0)
print(x[0, 0])
print(y[0, :])
# Out:
# [1.         0.01068939 0.01073847 0.00571192 0.00773082 0.23788297]
# [0.]

# %%
# Directory Config
neural_path = 'neural_network'
save_path_dir='prediction1'

if not os.path.exists(f'{neural_path}/{save_path_dir}'):
    os.makedirs(f'{neural_path}/{save_path_dir}')

checkpoint = ModelCheckpoint(
    f'{neural_path}/{save_path_dir}/saved_model.keras',
    verbose=1,
    monitor='val_f1_score',
    save_weights_only=False,
    save_best_only=True,
    mode='max')

earlystop = EarlyStopping(
    monitor="val_f1_score",
    min_delta=0,
    patience=20,
    verbose=0,
    mode="max",
    baseline=None,
    restore_best_weights=False
)

import pickle
# file = open(f'data/scaler_SP500.pkl','rb')
# scaler=pickle.load(file)
scaler=None
init_neuron=64
learning_rate=0.0001
model = build_model(time_series,num_features,init_neuron=init_neuron,learning_rate=learning_rate,scaler=scaler)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Input (InputLayer)          [(None, 52, 6)]              0         []
#
#  Encoder (GRU)               [(None, 52, 64),             13824     ['Input[0][0]']
#                               (None, 64)]
#
#  Attention (Attention)       (None, 52, 64)               0         ['Encoder[0][0]',
#                                                                      'Encoder[0][1]']
#
#  Concatenate (Concatenate)   (None, 52, 70)               0         ['Attention[0][0]',
#                                                                      'Input[0][0]']
#
#  Decoder (GRU)               (None, 64)                   26112     ['Concatenate[0][0]',
#                                                                      'Encoder[0][1]']
#
#  flatten (Flatten)           (None, 64)                   0         ['Decoder[0][0]']
#
#  dense (Dense)               (None, 1)                    65        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 40001 (156.25 KB)
# Trainable params: 40001 (156.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# from keras.utils import plot_model
# plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
history = model.fit(train_generator, batch_size=batch_size, epochs=2000, validation_data=val_generator, callbacks=[checkpoint, earlystop])
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model F1')
plt.ylabel('F1')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
print(f"Highest Val F1: {max(history.history['val_f1_score'])}")
# Out:
# Epoch 1/2000
# 48/48 [==============================] - ETA: 0s - loss: 2.2366 - binary_accuracy: 0.5752 - f1_score: 0.5963
# Epoch 1: val_f1_score improved from -inf to 0.59186, saving model to neural_network/attention_t20_fullFeatures_encode_decode/saved_model.keras
# 48/48 [==============================] - 23s 367ms/step - loss: 2.2366 - binary_accuracy: 0.5752 - f1_score: 0.5963 - val_loss: 1.0618 - val_binary_accuracy: 0.5788 - val_f1_score: 0.5919
# Epoch 2/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.8755 - binary_accuracy: 0.5814 - f1_score: 0.5950
# Epoch 2: val_f1_score improved from 0.59186 to 0.59315, saving model to neural_network/attention_t20_fullFeatures_encode_decode/saved_model.keras
# 48/48 [==============================] - 15s 315ms/step - loss: 0.8755 - binary_accuracy: 0.5814 - f1_score: 0.5950 - val_loss: 0.7956 - val_binary_accuracy: 0.5766 - val_f1_score: 0.5931
# Epoch 3/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.7745 - binary_accuracy: 0.5807 - f1_score: 0.5879
# Epoch 3: val_f1_score improved from 0.59315 to 0.59379, saving model to neural_network/attention_t20_fullFeatures_encode_decode/saved_model.keras
# 48/48 [==============================] - 16s 339ms/step - loss: 0.7745 - binary_accuracy: 0.5807 - f1_score: 0.5879 - val_loss: 0.7903 - val_binary_accuracy: 0.5755 - val_f1_score: 0.5938
# Epoch 4/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.7552 - binary_accuracy: 0.5983 - f1_score: 0.5675
# Epoch 4: val_f1_score did not improve from 0.59379
# 48/48 [==============================] - 16s 345ms/step - loss: 0.7552 - binary_accuracy: 0.5983 - f1_score: 0.5675 - val_loss: 0.7710 - val_binary_accuracy: 0.5715 - val_f1_score: 0.5928
# Epoch 5/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.8083 - binary_accuracy: 0.5833 - f1_score: 0.5856
# Epoch 5: val_f1_score did not improve from 0.59379
# 48/48 [==============================] - 11s 219ms/step - loss: 0.8083 - binary_accuracy: 0.5833 - f1_score: 0.5856 - val_loss: 0.8016 - val_binary_accuracy: 0.5783 - val_f1_score: 0.5929
# Epoch 6/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.7483 - binary_accuracy: 0.5911 - f1_score: 0.5784
# Epoch 6: val_f1_score did not improve from 0.59379
# 48/48 [==============================] - 15s 307ms/step - loss: 0.7483 - binary_accuracy: 0.5911 - f1_score: 0.5784 - val_loss: 0.7394 - val_binary_accuracy: 0.5754 - val_f1_score: 0.5935
# Epoch 7/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.7251 - binary_accuracy: 0.5830 - f1_score: 0.5856
# Epoch 7: val_f1_score did not improve from 0.59379
# 48/48 [==============================] - 15s 324ms/step - loss: 0.7251 - binary_accuracy: 0.5830 - f1_score: 0.5856 - val_loss: 0.7171 - val_binary_accuracy: 0.5785 - val_f1_score: 0.5926
# Epoch 8/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.7045 - binary_accuracy: 0.5924 - f1_score: 0.5774
# Epoch 8: val_f1_score did not improve from 0.59379
# 48/48 [==============================] - 11s 236ms/step - loss: 0.7045 - binary_accuracy: 0.5924 - f1_score: 0.5774 - val_loss: 0.7044 - val_binary_accuracy: 0.5768 - val_f1_score: 0.5931
# Epoch 9/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6919 - binary_accuracy: 0.5817 - f1_score: 0.5905
# Epoch 9: val_f1_score did not improve from 0.59379
# 48/48 [==============================] - 15s 307ms/step - loss: 0.6919 - binary_accuracy: 0.5817 - f1_score: 0.5905 - val_loss: 0.6998 - val_binary_accuracy: 0.5760 - val_f1_score: 0.5931
# Epoch 10/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6978 - binary_accuracy: 0.5807 - f1_score: 0.5924
# Epoch 10: val_f1_score did not improve from 0.59379
# 48/48 [==============================] - 11s 236ms/step - loss: 0.6978 - binary_accuracy: 0.5807 - f1_score: 0.5924 - val_loss: 0.7021 - val_binary_accuracy: 0.5717 - val_f1_score: 0.5937
# Epoch 11/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6939 - binary_accuracy: 0.5824 - f1_score: 0.5899
# Epoch 11: val_f1_score did not improve from 0.59379
# 48/48 [==============================] - 16s 340ms/step - loss: 0.6939 - binary_accuracy: 0.5824 - f1_score: 0.5899 - val_loss: 0.6939 - val_binary_accuracy: 0.5762 - val_f1_score: 0.5926
# Epoch 12/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6995 - binary_accuracy: 0.5749 - f1_score: 0.5950
# Epoch 12: val_f1_score did not improve from 0.59379
# 48/48 [==============================] - 15s 325ms/step - loss: 0.6995 - binary_accuracy: 0.5749 - f1_score: 0.5950 - val_loss: 0.6926 - val_binary_accuracy: 0.5779 - val_f1_score: 0.5928
# Epoch 13/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6948 - binary_accuracy: 0.5853 - f1_score: 0.5791
# Epoch 13: val_f1_score did not improve from 0.59379
# 48/48 [==============================] - 15s 308ms/step - loss: 0.6948 - binary_accuracy: 0.5853 - f1_score: 0.5791 - val_loss: 0.6929 - val_binary_accuracy: 0.5755 - val_f1_score: 0.5934
# Epoch 14/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6781 - binary_accuracy: 0.5954 - f1_score: 0.5722
# Epoch 14: val_f1_score did not improve from 0.59379
# 48/48 [==============================] - 15s 309ms/step - loss: 0.6781 - binary_accuracy: 0.5954 - f1_score: 0.5722 - val_loss: 0.6964 - val_binary_accuracy: 0.5776 - val_f1_score: 0.5924
# Epoch 15/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6868 - binary_accuracy: 0.5765 - f1_score: 0.5934
# Epoch 15: val_f1_score did not improve from 0.59379
# 48/48 [==============================] - 15s 309ms/step - loss: 0.6868 - binary_accuracy: 0.5765 - f1_score: 0.5934 - val_loss: 0.6988 - val_binary_accuracy: 0.5733 - val_f1_score: 0.5928
# Epoch 16/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6892 - binary_accuracy: 0.5742 - f1_score: 0.5928
# Epoch 16: val_f1_score improved from 0.59379 to 0.59392, saving model to neural_network/attention_t20_fullFeatures_encode_decode/saved_model.keras
# 48/48 [==============================] - 11s 237ms/step - loss: 0.6892 - binary_accuracy: 0.5742 - f1_score: 0.5928 - val_loss: 0.6934 - val_binary_accuracy: 0.5725 - val_f1_score: 0.5939
# Epoch 17/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6913 - binary_accuracy: 0.5895 - f1_score: 0.5755
# Epoch 17: val_f1_score did not improve from 0.59392
# 48/48 [==============================] - 15s 320ms/step - loss: 0.6913 - binary_accuracy: 0.5895 - f1_score: 0.5755 - val_loss: 0.6898 - val_binary_accuracy: 0.5746 - val_f1_score: 0.5922
# Epoch 18/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6850 - binary_accuracy: 0.5804 - f1_score: 0.5869
# Epoch 18: val_f1_score did not improve from 0.59392
# 48/48 [==============================] - 10s 203ms/step - loss: 0.6850 - binary_accuracy: 0.5804 - f1_score: 0.5869 - val_loss: 0.6914 - val_binary_accuracy: 0.5755 - val_f1_score: 0.5925
# Epoch 19/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6891 - binary_accuracy: 0.5771 - f1_score: 0.5908
# Epoch 19: val_f1_score did not improve from 0.59392
# 48/48 [==============================] - 16s 334ms/step - loss: 0.6891 - binary_accuracy: 0.5771 - f1_score: 0.5908 - val_loss: 0.6871 - val_binary_accuracy: 0.5777 - val_f1_score: 0.5931
# Epoch 20/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6986 - binary_accuracy: 0.5856 - f1_score: 0.5820
# Epoch 20: val_f1_score did not improve from 0.59392
# 48/48 [==============================] - 15s 307ms/step - loss: 0.6986 - binary_accuracy: 0.5856 - f1_score: 0.5820 - val_loss: 0.6897 - val_binary_accuracy: 0.5732 - val_f1_score: 0.5934
# Epoch 21/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6793 - binary_accuracy: 0.5850 - f1_score: 0.5843
# Epoch 21: val_f1_score did not improve from 0.59392
# 48/48 [==============================] - 10s 212ms/step - loss: 0.6793 - binary_accuracy: 0.5850 - f1_score: 0.5843 - val_loss: 0.6885 - val_binary_accuracy: 0.5762 - val_f1_score: 0.5931
# Epoch 22/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6842 - binary_accuracy: 0.5758 - f1_score: 0.5960
# Epoch 22: val_f1_score did not improve from 0.59392
# 48/48 [==============================] - 16s 330ms/step - loss: 0.6842 - binary_accuracy: 0.5758 - f1_score: 0.5960 - val_loss: 0.6871 - val_binary_accuracy: 0.5725 - val_f1_score: 0.5937
# Epoch 23/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6754 - binary_accuracy: 0.5902 - f1_score: 0.5820
# Epoch 23: val_f1_score did not improve from 0.59392
# 48/48 [==============================] - 17s 348ms/step - loss: 0.6754 - binary_accuracy: 0.5902 - f1_score: 0.5820 - val_loss: 0.6877 - val_binary_accuracy: 0.5732 - val_f1_score: 0.5920
# Epoch 24/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6870 - binary_accuracy: 0.5869 - f1_score: 0.5807
# Epoch 24: val_f1_score did not improve from 0.59392
# 48/48 [==============================] - 15s 310ms/step - loss: 0.6870 - binary_accuracy: 0.5869 - f1_score: 0.5807 - val_loss: 0.6890 - val_binary_accuracy: 0.5732 - val_f1_score: 0.5933
# Epoch 25/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6864 - binary_accuracy: 0.5752 - f1_score: 0.5928
# Epoch 25: val_f1_score did not improve from 0.59392
# 48/48 [==============================] - 12s 243ms/step - loss: 0.6864 - binary_accuracy: 0.5752 - f1_score: 0.5928 - val_loss: 0.6871 - val_binary_accuracy: 0.5797 - val_f1_score: 0.5931
# Epoch 26/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6788 - binary_accuracy: 0.5811 - f1_score: 0.5843
# Epoch 26: val_f1_score improved from 0.59392 to 0.59405, saving model to neural_network/attention_t20_fullFeatures_encode_decode/saved_model.keras
# 48/48 [==============================] - 15s 322ms/step - loss: 0.6788 - binary_accuracy: 0.5811 - f1_score: 0.5843 - val_loss: 0.6867 - val_binary_accuracy: 0.5750 - val_f1_score: 0.5941
# Epoch 27/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6817 - binary_accuracy: 0.5804 - f1_score: 0.5921
# Epoch 27: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 11s 239ms/step - loss: 0.6817 - binary_accuracy: 0.5804 - f1_score: 0.5921 - val_loss: 0.6860 - val_binary_accuracy: 0.5777 - val_f1_score: 0.5929
# Epoch 28/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6839 - binary_accuracy: 0.5791 - f1_score: 0.5892
# Epoch 28: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 17s 356ms/step - loss: 0.6839 - binary_accuracy: 0.5791 - f1_score: 0.5892 - val_loss: 0.6859 - val_binary_accuracy: 0.5747 - val_f1_score: 0.5925
# Epoch 29/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6805 - binary_accuracy: 0.5931 - f1_score: 0.5722
# Epoch 29: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 16s 330ms/step - loss: 0.6805 - binary_accuracy: 0.5931 - f1_score: 0.5722 - val_loss: 0.6856 - val_binary_accuracy: 0.5757 - val_f1_score: 0.5924
# Epoch 30/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6807 - binary_accuracy: 0.5918 - f1_score: 0.5794
# Epoch 30: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 15s 308ms/step - loss: 0.6807 - binary_accuracy: 0.5918 - f1_score: 0.5794 - val_loss: 0.6852 - val_binary_accuracy: 0.5711 - val_f1_score: 0.5933
# Epoch 31/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6737 - binary_accuracy: 0.6022 - f1_score: 0.5662
# Epoch 31: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 15s 307ms/step - loss: 0.6737 - binary_accuracy: 0.6022 - f1_score: 0.5662 - val_loss: 0.6845 - val_binary_accuracy: 0.5783 - val_f1_score: 0.5925
# Epoch 32/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6895 - binary_accuracy: 0.5654 - f1_score: 0.6024
# Epoch 32: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 16s 346ms/step - loss: 0.6895 - binary_accuracy: 0.5654 - f1_score: 0.6024 - val_loss: 0.6839 - val_binary_accuracy: 0.5758 - val_f1_score: 0.5926
# Epoch 33/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6824 - binary_accuracy: 0.5771 - f1_score: 0.5979
# Epoch 33: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 15s 325ms/step - loss: 0.6824 - binary_accuracy: 0.5771 - f1_score: 0.5979 - val_loss: 0.6873 - val_binary_accuracy: 0.5723 - val_f1_score: 0.5939
# Epoch 34/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6772 - binary_accuracy: 0.5895 - f1_score: 0.5863
# Epoch 34: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 16s 330ms/step - loss: 0.6772 - binary_accuracy: 0.5895 - f1_score: 0.5863 - val_loss: 0.6841 - val_binary_accuracy: 0.5766 - val_f1_score: 0.5926
# Epoch 35/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6836 - binary_accuracy: 0.5742 - f1_score: 0.5969
# Epoch 35: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 15s 307ms/step - loss: 0.6836 - binary_accuracy: 0.5742 - f1_score: 0.5969 - val_loss: 0.6844 - val_binary_accuracy: 0.5779 - val_f1_score: 0.5937
# Epoch 36/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6733 - binary_accuracy: 0.5964 - f1_score: 0.5778
# Epoch 36: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 13s 282ms/step - loss: 0.6733 - binary_accuracy: 0.5964 - f1_score: 0.5778 - val_loss: 0.6844 - val_binary_accuracy: 0.5779 - val_f1_score: 0.5922
# Epoch 37/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6772 - binary_accuracy: 0.5843 - f1_score: 0.5791
# Epoch 37: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 15s 309ms/step - loss: 0.6772 - binary_accuracy: 0.5843 - f1_score: 0.5791 - val_loss: 0.6840 - val_binary_accuracy: 0.5760 - val_f1_score: 0.5935
# Epoch 38/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6866 - binary_accuracy: 0.5879 - f1_score: 0.5784
# Epoch 38: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 15s 309ms/step - loss: 0.6866 - binary_accuracy: 0.5879 - f1_score: 0.5784 - val_loss: 0.6852 - val_binary_accuracy: 0.5723 - val_f1_score: 0.5928
# Epoch 39/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6821 - binary_accuracy: 0.5765 - f1_score: 0.5892
# Epoch 39: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 16s 345ms/step - loss: 0.6821 - binary_accuracy: 0.5765 - f1_score: 0.5892 - val_loss: 0.6848 - val_binary_accuracy: 0.5757 - val_f1_score: 0.5933
# Epoch 40/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6763 - binary_accuracy: 0.5938 - f1_score: 0.5814
# Epoch 40: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 11s 219ms/step - loss: 0.6763 - binary_accuracy: 0.5938 - f1_score: 0.5814 - val_loss: 0.6816 - val_binary_accuracy: 0.5780 - val_f1_score: 0.5924
# Epoch 41/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6737 - binary_accuracy: 0.5973 - f1_score: 0.5778
# Epoch 41: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 11s 239ms/step - loss: 0.6737 - binary_accuracy: 0.5973 - f1_score: 0.5778 - val_loss: 0.6843 - val_binary_accuracy: 0.5764 - val_f1_score: 0.5931
# Epoch 42/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6776 - binary_accuracy: 0.5859 - f1_score: 0.5886
# Epoch 42: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 15s 307ms/step - loss: 0.6776 - binary_accuracy: 0.5859 - f1_score: 0.5886 - val_loss: 0.6836 - val_binary_accuracy: 0.5767 - val_f1_score: 0.5931
# Epoch 43/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6812 - binary_accuracy: 0.5723 - f1_score: 0.5918
# Epoch 43: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 15s 311ms/step - loss: 0.6812 - binary_accuracy: 0.5723 - f1_score: 0.5918 - val_loss: 0.6848 - val_binary_accuracy: 0.5715 - val_f1_score: 0.5929
# Epoch 44/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6745 - binary_accuracy: 0.5957 - f1_score: 0.5765
# Epoch 44: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 16s 347ms/step - loss: 0.6745 - binary_accuracy: 0.5957 - f1_score: 0.5765 - val_loss: 0.6843 - val_binary_accuracy: 0.5759 - val_f1_score: 0.5933
# Epoch 45/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6708 - binary_accuracy: 0.6022 - f1_score: 0.5751
# Epoch 45: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 16s 345ms/step - loss: 0.6708 - binary_accuracy: 0.6022 - f1_score: 0.5751 - val_loss: 0.6830 - val_binary_accuracy: 0.5792 - val_f1_score: 0.5931
# Epoch 46/2000
# 48/48 [==============================] - ETA: 0s - loss: 0.6802 - binary_accuracy: 0.5820 - f1_score: 0.5911
# Epoch 46: val_f1_score did not improve from 0.59405
# 48/48 [==============================] - 16s 342ms/step - loss: 0.6802 - binary_accuracy: 0.5820 - f1_score: 0.5911 - val_loss: 0.6857 - val_binary_accuracy: 0.5712 - val_f1_score: 0.5925
# Highest Val F1: 0.5940503478050232

# %%
total_count = 0
correct_count = 0
uptrend_correct = 0 #Correct Uptrend
uptrend_wrong = 0
downtrend_correct = 0 #Correct Downtrend
downtrend_wrong = 0
for i in range(len(val_generator)):
   x, y_actual = val_generator.__getitem__(i)
   total_count += y_actual.shape[0]
   y_pred = model.predict(x,verbose=0)
   y_actual_label = y_actual[:,:].reshape(-1)
   y_pred_label = (y_pred[:,:].reshape(-1)) >= 0.5

   correct = y_actual_label == y_pred_label
   correct_count += np.count_nonzero(correct)
   uptrend_correct += np.count_nonzero(correct & y_pred_label)
   downtrend_correct += np.count_nonzero(correct & ~y_pred_label)
   uptrend_wrong += np.count_nonzero(~correct & y_pred_label)
   downtrend_wrong += np.count_nonzero(~correct & ~y_pred_label)





print(f"Accuracy: {correct_count/total_count}")
print(f"Total: {total_count}")
print(f"Correct Count: {correct_count}")
print("")
print(f"Uptrend Total: {uptrend_correct+uptrend_wrong}")
print(f"Uptrend Correct: {uptrend_correct}")
print(f"Uptrend Accuracy: {uptrend_correct/(uptrend_correct+uptrend_wrong)}")
print("")
print(f"Downtrend Total: {downtrend_correct+downtrend_wrong}")
print(f"Downtrend Correct: {downtrend_correct}")
print(f"Downtrend Accuracy: {downtrend_correct/(downtrend_correct+downtrend_wrong)}")

print(y_actual[0,:])
print(y_pred[0,:])
# Out:
# Accuracy: 0.5786458333333333
# Total: 7680
# Correct Count: 4444
#
# Uptrend Total: 587
# Uptrend Correct: 265
# Uptrend Accuracy: 0.4514480408858603
#
# Downtrend Total: 7093
# Downtrend Correct: 4179
# Downtrend Accuracy: 0.5891724235161426
# [0.]
# [0.4173752]
